# %% [markdown]
# <a href="https://colab.research.google.com/github/K-J-HYEON/tzip/blob/main/gen_test_%EC%88%98%EC%A0%95(%EC%B5%9C%EC%A2%85).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip uninstall opencv-python
# Out:
# Mounted at /content/drive
# Uninstalling opencv-python-4.1.2.30:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python-4.1.2.30.dist-info/*
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-4.1.2.30

# %%
# %cd /content/drive/Shareddrives/십년증수/cv2_cuda
# !cp cv2.cpython-37m-x86_64-liynux-gnu.so /usr/local/lib/python3.7/dist-packages
# Out:
# /content/drive/Shareddrives/십년증수/cv2_cuda

# %%
# !pip install opencv-python==4.5.1.48
# Out:
# Collecting opencv-python==4.5.1.48
#   Downloading https://files.pythonhosted.org/packages/0f/13/192104516c4a3d92dc6b5e106ffcfbf0fe35f3c4faa49650205ff652af72/opencv_python-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl (50.4MB)
#      |████████████████████████████████| 50.4MB 53kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.5.1.48) (1.19.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip uninstall opencv-python
# %cd /content/drive/MyDrive/cv2_cuda
# !cp cv2.cpython-37m-x86_64-linux-gnu.so /usr/local/lib/python3.7/dist-packages
import cv2
print(cv2.__version__)
print(cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Uninstalling opencv-python-4.5.1.48:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python-4.5.1.48.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Concurrent-21c64331.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Core-d92f2856.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Gui-ca084835.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Test-9d4ee57e.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Widgets-0e1d98b5.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5XcbQpa-70670cdb.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libX11-xcb-1ae4fd0e.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libXau-00ec42fe.so.6.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavcodec-8daa01ff.so.58.109.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavformat-06a336f2.so.58.61.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavutil-01d48d95.so.56.60.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libcrypto-098682aa.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libfreetype-8d3bcff4.so.6.14.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libpng15-c2ffaf3d.so.15.13.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libssl-f3db6a3b.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libswresample-4767dc06.so.3.8.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libswscale-2d2bce5d.so.5.8.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libvpx-14094576.so.6.3.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-icccm-413c9f41.so.4.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-image-e82a276d.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-keysyms-21015570.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-randr-a96a5a87.so.0.1.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-render-637b984a.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-render-util-43ce00f5.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-shape-25c2b258.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-shm-7a199f70.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-sync-89374f40.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-util-4d666913.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xfixes-9be3ba6f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xinerama-ae147f87.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xkb-9ba31ab3.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxkbcommon-71ae2972.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxkbcommon-x11-c65ed502.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libz-d8a329de.so.1.2.7
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-4.5.1.48
# [Errno 2] No such file or directory: '/content/drive/MyDrive/cv2_cuda'
# /content/drive/Shareddrives/십년증수/cv2_cuda
# 4.5.2-pre
# 1

# %%
# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp yolo_classes.py /usr/local/lib/python3.7/dist-packages
# Out:
# /content/drive/Shareddrives/십년증수/openCV(colab_data)/data

# %%
# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp BODY_PARTS.py /usr/local/lib/python3.7/dist-packages

# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp POSE_PAIRS.py /usr/local/lib/python3.7/dist-packages

# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp proto_file_path.py /usr/local/lib/python3.7/dist-packages

# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp weights_file_path.py /usr/local/lib/python3.7/dist-packages

# %cd /content/drive/Shareddrives/십년증수/openCV(colab_data)/data
# !cp yolo_classes.py /usr/local/lib/python3.7/dist-packages

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from tqdm import tqdm
from yolo_classes import classes

proto_file = "/content/drive/Shareddrives/십년증수/project/data/mpi/pose_deploy_linevec_faster_4_stages.prototxt"
weights_file = "/content/drive/Shareddrives/십년증수/project/data_bak/data/pose_iter_160000.caffemodel"

BODY_PARTS_MPI = {0: "Head", 1: "Neck", 2: "RShoulder", 3: "RElbow", 4: "RWrist",
                  5: "LShoulder", 6: "LElbow", 7: "LWrist", 8: "RHip", 9: "RKnee",
                  10: "RAnkle", 11: "LHip", 12: "LKnee", 13: "LAnkle", 14: "Chest",
                  15: "Background"}

POSE_PAIRS_MPI = [[0, 1], [1, 2], [1, 5], [1, 14], [2, 3], [3, 4], [5, 6],
                  [6, 7], [8, 9], [9, 10], [11, 12], [12, 13], [14, 8], [14, 11]]

# %%
def yolo(size, score_threshold, nms_threshold):
    # YOLO 네트워크 불러오기
    weights = '/content/drive/Shareddrives/십년증수/openCV(colab_data)/yolov4.weights'
    cfg = '/content/drive/Shareddrives/십년증수/openCV(colab_data)/yolov4.cfg'
    net = cv2.dnn.readNet(weights, cfg)
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # GPU 사용
    net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

    # 클래스의 갯수만큼 랜덤 RGB 배열을 생성
    colors = np.random.uniform(0, 255, size=(len(classes), 3))

    # 이미지의 높이, 너비, 채널 받아오기
    height, width, channels = frame_origin.shape

    # 네트워크에 넣기 위한 전처리

    
    
    blob = cv2.dnn.blobFromImage(frame_origin, 0.00392, (size, size), (0, 0, 0), True, crop=False)

    # 전처리된 blob 네트워크에 입력
    net.setInput(blob)

    # 결과 받아오기
    outs = net.forward(output_layers)

    # 각각의 데이터를 저장할 리스트 생성 및 초기화
    class_ids = []
    confidences = []
    boxes = []
    nms_boxes.clear()

    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.1:
                # 탐지된 객체의 너비, 높이 및 중앙 좌표값 찾기
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # 객체의 사각형 테두리 중 좌상단 좌표값 찾기
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    print('│' + " YOLO ".center(90, '─') + '│')
    # 후보 박스(x, y, width, height) 출력
    # print(f"│boxes: {boxes}")
    # print(f"│confidences: {confidences}")

    # 노이즈 제거 (Non Maximum Suppression) (겹쳐있는 박스 중 상자가 물체일 확률이 가장 높은 박스만 남겨둠)
    indexes = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=score_threshold, nms_threshold=nms_threshold)

    # NMS 을 통해 걸러진 박스의 인덱스 출력
    # print(f"│indexes: ", end='')
    # for index in indexes:
    #     print(index, end=' ')
    # print()

    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            class_name = classes[class_ids[i]]

            # 중복된 객체를 이름 뒤 숫자를 추가하여 구분
            class_name += '_1'
            num = 1
            while class_name in nms_boxes.keys():
                num += 1
                class_name = class_name[:-1] + str(num)

            # 프레임에 작성할 텍스트 및 색깔 지정
            label = f"{class_name}: {confidences[i]:.2f}"
            color = colors[class_ids[i]]

            # 프레임에 사각형 테두리 그리기 및 텍스트 쓰기
            cv2.rectangle(frame_drawn, (x, y), (x + w, y + h), color, 2)
            cv2.rectangle(frame_drawn, (x - 1, y), (x + len(class_name) * 13 + 80, y - 25), color, -1)
            cv2.putText(frame_drawn, label, (x, y - 8), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (255, 255, 255), 2)

            # 탐지된 객체의 정보 출력 및 nms_boxex 에 저장
            print('{0}│'.format(
                f"│ [{class_name}] conf: {confidences[i]} / x: {x} / y: {y} / width: {w} / height: {h}".ljust(91, ' ')))
            nms_boxes[class_name] = [x, y, w, h]

# %%
def output_keypoints(proto_file, weights_file, threshold, BODY_PARTS):
    global points

    # 네트워크 불러오기
    net = cv2.dnn.readNetFromCaffe(proto_file, weights_file)

    # GPU 사용
    net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

    # 입력 이미지의 사이즈 정의
    image_height = 368
    image_width = 368

    # 네트워크에 넣기 위한 전처리
    input_blob = cv2.dnn.blobFromImage(frame_origin, 1.0 / 255, (image_width, image_height), (0, 0, 0),
                                       swapRB=False, crop=False)

    # 전처리된 blob 네트워크에 입력
    net.setInput(input_blob)

    # 결과 받아오기
    out = net.forward()
    # The output is a 4D matrix :
    # The first dimension being the image ID ( in case you pass more than one image to the network ).
    # The second dimension indicates the index of a keypoint.
    # The model produces Confidence Maps and Part Affinity maps which are all concatenated.
    # For COCO model it consists of 57 parts – 18 keypoint confidence Maps + 1 background + 19*2 Part Affinity Maps. Similarly, for MPI, it produces 44 points.
    # We will be using only the first few points which correspond to Keypoints.
    # The third dimension is the height of the output map.
    out_height = out.shape[2]
    # The fourth dimension is the width of the output map.
    out_width = out.shape[3]

    # 원본 이미지의 높이, 너비를 받아오기
    frame_height, frame_width = frame_origin.shape[:2]

    # 포인트 리스트 초기화
    points = []

    print('│' + " POINT ".center(90, '─') + '│')
    for i in range(len(BODY_PARTS)):

        # 신체 부위의 confidence map
        prob_map = out[0, i, :, :]

        # 최소값, 최대값, 최소값 위치, 최대값 위치
        min_val, prob, min_loc, point = cv2.minMaxLoc(prob_map)

        # 원본 이미지에 맞게 포인트 위치 조정
        x = int((frame_width * point[0]) / out_width)
        y = int((frame_height * point[1]) / out_height)

        if prob > threshold:  # [pointed]
            cv2.circle(frame_drawn, (x, y), 5, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
            cv2.putText(frame_drawn, str(i), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 1,
                        lineType=cv2.LINE_AA)

            points.append((x, y))
            print('{0}│'.format(
                f"│ [pointed] {BODY_PARTS[i]} ({i}) => prob: {prob:.5f} / x: {x} / y: {y}".ljust(91, ' ')))

        else:  # [not pointed]
            cv2.circle(frame_drawn, (x, y), 5, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
            cv2.putText(frame_drawn, str(i), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 1,
                        lineType=cv2.LINE_AA)

            points.append(None)
            print('{0}│'.format(
                f"│ [not pointed] {BODY_PARTS[i]} ({i}) => prob: {prob:.5f} / x: {x} / y: {y}".ljust(91, ' ')))

# %%
def output_keypoints_with_lines(POSE_PAIRS):
    print('│' + " LINK ".center(90, '─') + '│')
    for pair in POSE_PAIRS:
        part_a = pair[0]  # 0 (Head)
        part_b = pair[1]  # 1 (Neck)
        if points[part_a] and points[part_b]:
            print('{0}│'.format(f"│ [linked] {part_a} {points[part_a]} <=> {part_b} {points[part_b]}".ljust(91, ' ')))
            cv2.line(frame_drawn, points[part_a], points[part_b], (0, 255, 0), 2)
        else:
            print(
                '{0}│'.format(f"│ [not linked] {part_a} {points[part_a]} <=> {part_b} {points[part_b]}".ljust(91, ' ')))

# %%
def in_box():
    print('│' + " IN BOX ".center(90, '─') + '│')
    for key, value in nms_boxes.items():
        if key.split('_')[0] != "person":  # person 오브젝트 제외
            points_string = ""
            for index, point in enumerate(points):
                if point is not None and index != 25:  # point 가 없을 경우와 배경일 경우 제외
                    x = value[0]
                    y = value[1]
                    width = value[0] + value[2]
                    height = value[1] + value[3]
                    if (point[0] > x) and (point[0] < width) and (point[1] > y) and (point[1] < height):
                        points_string += str(index) + ' '
            if len(points_string) > 0:
                print('│{0}│'.format((f" [{key}] " + points_string).ljust(90, ' ')))

# %%
# 키포인트를 저장할 리스트 생성
points = []

# NMS 를 거친 객체 box 들의 정보를 저장할 딕셔너리 생성 (in_box() 함수에서 사용됨)
nms_boxes = {}

# 입력 사이즈 리스트 (Yolo 에서 사용되는 네크워크 입력 이미지 사이즈)
size_list = [320, 416, 608]

# %%
# 비디오 경로
video = "/content/drive/Shareddrives/십년증수/project/참고_KJH/dance.mp4"
capture = cv2.VideoCapture(video)
total_frame = int(capture.get(cv2.CAP_PROP_FRAME_COUNT))

for now_frame in tqdm(range(total_frame)):
    ret, frame = capture.read()

    frame_origin = frame  # 네트워크에 넣을 프레임
    frame_drawn = frame  # 텍스트 및 테두리가 그려질 프레임
    yolo(size=size_list[1], score_threshold=0.4, nms_threshold=0.4)
    output_keypoints(proto_file, weights_file, threshold=0, BODY_PARTS=BODY_PARTS_MPI)
    output_keypoints_with_lines(POSE_PAIRS=POSE_PAIRS_MPI)
    in_box()

    # 이미지 파일 생성
    cv2.imwrite(f"/content/drive/MyDrive/test/{now_frame:.0f}.jpg", frame_drawn)

capture.release()
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9982743263244629 / x: 283 / y: 94 / width: 202 / height: 362          │
#   0%|          | 1/210 [00:01<04:20,  1.25s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.81940 / x: 315 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.75799 / x: 334 / y: 146                                    │
# │ [pointed] RShoulder (2) => prob: 0.72826 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.71158 / x: 297 / y: 240                                  │
# │ [pointed] RWrist (4) => prob: 0.64425 / x: 278 / y: 292                                  │
# │ [pointed] LShoulder (5) => prob: 0.66409 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.53149 / x: 352 / y: 219                                  │
# │ [pointed] LWrist (7) => prob: 0.19213 / x: 315 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.67351 / x: 334 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.71071 / x: 315 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.80324 / x: 315 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.57703 / x: 371 / y: 271                                   │
# │ [pointed] LKnee (12) => prob: 0.77394 / x: 408 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.67527 / x: 445 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.74469 / x: 352 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00472 / x: 464 / y: 323                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 93) <=> 1 (334, 146)                                                    │
# │ [linked] 1 (334, 146) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 146) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 146) <=> 14 (352, 219)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (297, 240)                                                   │
# │ [linked] 3 (297, 240) <=> 4 (278, 292)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (352, 219)                                                   │
# │ [linked] 6 (352, 219) <=> 7 (315, 240)                                                   │
# │ [linked] 8 (334, 281) <=> 9 (315, 354)                                                   │
# │ [linked] 9 (315, 354) <=> 10 (315, 427)                                                  │
# │ [linked] 11 (371, 271) <=> 12 (408, 344)                                                 │
# │ [linked] 12 (408, 344) <=> 13 (445, 417)                                                 │
# │ [linked] 14 (352, 219) <=> 8 (334, 281)                                                  │
# │ [linked] 14 (352, 219) <=> 11 (371, 271)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9981937408447266 / x: 256 / y: 94 / width: 228 / height: 360          │
#   1%|          | 2/210 [00:02<04:17,  1.24s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.75028 / x: 334 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.76443 / x: 334 / y: 146                                    │
# │ [pointed] RShoulder (2) => prob: 0.72751 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.70414 / x: 297 / y: 229                                  │
# │ [pointed] RWrist (4) => prob: 0.62869 / x: 278 / y: 271                                  │
# │ [pointed] LShoulder (5) => prob: 0.64628 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.47153 / x: 352 / y: 208                                  │
# │ [pointed] LWrist (7) => prob: 0.26828 / x: 334 / y: 229                                  │
# │ [pointed] RHip (8) => prob: 0.65052 / x: 334 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.73823 / x: 315 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.86007 / x: 315 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.63465 / x: 389 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.69183 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.61327 / x: 464 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.70775 / x: 352 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00484 / x: 556 / y: 365                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (334, 93) <=> 1 (334, 146)                                                    │
# │ [linked] 1 (334, 146) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 146) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 146) <=> 14 (352, 219)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (297, 229)                                                   │
# │ [linked] 3 (297, 229) <=> 4 (278, 271)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (352, 208)                                                   │
# │ [linked] 6 (352, 208) <=> 7 (334, 229)                                                   │
# │ [linked] 8 (334, 281) <=> 9 (315, 354)                                                   │
# │ [linked] 9 (315, 354) <=> 10 (315, 427)                                                  │
# │ [linked] 11 (389, 281) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (464, 427)                                                 │
# │ [linked] 14 (352, 219) <=> 8 (334, 281)                                                  │
# │ [linked] 14 (352, 219) <=> 11 (389, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9984205365180969 / x: 235 / y: 95 / width: 257 / height: 358          │
#   1%|▏         | 3/210 [00:03<04:12,  1.22s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.83479 / x: 334 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.77901 / x: 334 / y: 135                                    │
# │ [pointed] RShoulder (2) => prob: 0.75063 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.68837 / x: 297 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.58815 / x: 259 / y: 260                                  │
# │ [pointed] LShoulder (5) => prob: 0.71222 / x: 371 / y: 146                               │
# │ [pointed] LElbow (6) => prob: 0.48710 / x: 371 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.55991 / x: 334 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.58241 / x: 352 / y: 271                                    │
# │ [pointed] RKnee (9) => prob: 0.66321 / x: 334 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.84266 / x: 315 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.63270 / x: 389 / y: 271                                   │
# │ [pointed] LKnee (12) => prob: 0.78697 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.64888 / x: 464 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.62277 / x: 371 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00480 / x: 798 / y: 219                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (334, 93) <=> 1 (334, 135)                                                    │
# │ [linked] 1 (334, 135) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 135) <=> 5 (371, 146)                                                   │
# │ [linked] 1 (334, 135) <=> 14 (371, 219)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (297, 219)                                                   │
# │ [linked] 3 (297, 219) <=> 4 (259, 260)                                                   │
# │ [linked] 5 (371, 146) <=> 6 (371, 198)                                                   │
# │ [linked] 6 (371, 198) <=> 7 (334, 240)                                                   │
# │ [linked] 8 (352, 271) <=> 9 (334, 354)                                                   │
# │ [linked] 9 (334, 354) <=> 10 (315, 427)                                                  │
# │ [linked] 11 (389, 271) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (464, 417)                                                 │
# │ [linked] 14 (371, 219) <=> 8 (352, 271)                                                  │
# │ [linked] 14 (371, 219) <=> 11 (389, 271)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9968766570091248 / x: 225 / y: 94 / width: 277 / height: 360          │
#   2%|▏         | 4/210 [00:04<04:08,  1.21s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.70909 / x: 315 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.79541 / x: 334 / y: 146                                    │
# │ [pointed] RShoulder (2) => prob: 0.74364 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.67230 / x: 278 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.66370 / x: 241 / y: 250                                  │
# │ [pointed] LShoulder (5) => prob: 0.65411 / x: 371 / y: 146                               │
# │ [pointed] LElbow (6) => prob: 0.51100 / x: 371 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.62789 / x: 352 / y: 250                                  │
# │ [pointed] RHip (8) => prob: 0.43110 / x: 389 / y: 271                                    │
# │ [pointed] RKnee (9) => prob: 0.61782 / x: 427 / y: 344                                   │
# │ [pointed] RAnkle (10) => prob: 0.62138 / x: 464 / y: 417                                 │
# │ [pointed] LHip (11) => prob: 0.44303 / x: 371 / y: 271                                   │
# │ [pointed] LKnee (12) => prob: 0.52112 / x: 334 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.59509 / x: 315 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.60330 / x: 352 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00571 / x: 575 / y: 354                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 93) <=> 1 (334, 146)                                                    │
# │ [linked] 1 (334, 146) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 146) <=> 5 (371, 146)                                                   │
# │ [linked] 1 (334, 146) <=> 14 (352, 219)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (278, 219)                                                   │
# │ [linked] 3 (278, 219) <=> 4 (241, 250)                                                   │
# │ [linked] 5 (371, 146) <=> 6 (371, 198)                                                   │
# │ [linked] 6 (371, 198) <=> 7 (352, 250)                                                   │
# │ [linked] 8 (389, 271) <=> 9 (427, 344)                                                   │
# │ [linked] 9 (427, 344) <=> 10 (464, 417)                                                  │
# │ [linked] 11 (371, 271) <=> 12 (334, 354)                                                 │
# │ [linked] 12 (334, 354) <=> 13 (315, 427)                                                 │
# │ [linked] 14 (352, 219) <=> 8 (389, 271)                                                  │
# │ [linked] 14 (352, 219) <=> 11 (371, 271)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9972004294395447 / x: 210 / y: 97 / width: 292 / height: 359          │
#   2%|▏         | 5/210 [00:06<04:06,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.73400 / x: 315 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.80974 / x: 334 / y: 146                                    │
# │ [pointed] RShoulder (2) => prob: 0.73571 / x: 315 / y: 166                               │
# │ [pointed] RElbow (3) => prob: 0.77071 / x: 278 / y: 208                                  │
# │ [pointed] RWrist (4) => prob: 0.73903 / x: 222 / y: 229                                  │
# │ [pointed] LShoulder (5) => prob: 0.71093 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.59756 / x: 389 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.69933 / x: 371 / y: 250                                  │
# │ [pointed] RHip (8) => prob: 0.56323 / x: 352 / y: 271                                    │
# │ [pointed] RKnee (9) => prob: 0.75727 / x: 334 / y: 344                                   │
# │ [pointed] RAnkle (10) => prob: 0.79112 / x: 315 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.51791 / x: 408 / y: 260                                   │
# │ [pointed] LKnee (12) => prob: 0.78576 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.72090 / x: 464 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.71376 / x: 371 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00733 / x: 538 / y: 333                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 93) <=> 1 (334, 146)                                                    │
# │ [linked] 1 (334, 146) <=> 2 (315, 166)                                                   │
# │ [linked] 1 (334, 146) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 146) <=> 14 (371, 219)                                                  │
# │ [linked] 2 (315, 166) <=> 3 (278, 208)                                                   │
# │ [linked] 3 (278, 208) <=> 4 (222, 229)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (389, 198)                                                   │
# │ [linked] 6 (389, 198) <=> 7 (371, 250)                                                   │
# │ [linked] 8 (352, 271) <=> 9 (334, 344)                                                   │
# │ [linked] 9 (334, 344) <=> 10 (315, 427)                                                  │
# │ [linked] 11 (408, 260) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (464, 427)                                                 │
# │ [linked] 14 (371, 219) <=> 8 (352, 271)                                                  │
# │ [linked] 14 (371, 219) <=> 11 (408, 260)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9947524070739746 / x: 215 / y: 102 / width: 287 / height: 356         │
#   3%|▎         | 6/210 [00:07<04:04,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.75150 / x: 315 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.78527 / x: 334 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.83170 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.80903 / x: 278 / y: 208                                  │
# │ [pointed] RWrist (4) => prob: 0.64799 / x: 241 / y: 208                                  │
# │ [pointed] LShoulder (5) => prob: 0.74559 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.79606 / x: 389 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.67200 / x: 408 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.65316 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.72288 / x: 334 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.74950 / x: 315 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.67933 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.65929 / x: 427 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.70266 / x: 464 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.62640 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00807 / x: 538 / y: 333                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 104) <=> 1 (334, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 156) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (278, 208)                                                   │
# │ [linked] 3 (278, 208) <=> 4 (241, 208)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (389, 198)                                                   │
# │ [linked] 6 (389, 198) <=> 7 (408, 240)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 354)                                                   │
# │ [linked] 9 (334, 354) <=> 10 (315, 427)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (427, 354)                                                 │
# │ [linked] 12 (427, 354) <=> 13 (464, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.996266782283783 / x: 224 / y: 107 / width: 279 / height: 353          │
#   3%|▎         | 7/210 [00:08<04:05,  1.21s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.77399 / x: 315 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.82561 / x: 334 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.77384 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.66662 / x: 278 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.60604 / x: 259 / y: 187                                  │
# │ [pointed] LShoulder (5) => prob: 0.77625 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.82503 / x: 389 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.68989 / x: 408 / y: 229                                  │
# │ [pointed] RHip (8) => prob: 0.69646 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.72864 / x: 334 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.71289 / x: 334 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.67993 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.64981 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.61169 / x: 464 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.63128 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00860 / x: 538 / y: 333                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 104) <=> 1 (334, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 156) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (278, 219)                                                   │
# │ [linked] 3 (278, 219) <=> 4 (259, 187)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (389, 198)                                                   │
# │ [linked] 6 (389, 198) <=> 7 (408, 229)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 354)                                                   │
# │ [linked] 9 (334, 354) <=> 10 (334, 427)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (464, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9985949397087097 / x: 252 / y: 115 / width: 247 / height: 348         │
#   4%|▍         | 8/210 [00:09<04:01,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.84200 / x: 315 / y: 114                                    │
# │ [pointed] Neck (1) => prob: 0.82555 / x: 334 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.71933 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.42033 / x: 334 / y: 208                                  │
# │ [pointed] RWrist (4) => prob: 0.36043 / x: 334 / y: 240                                  │
# │ [pointed] LShoulder (5) => prob: 0.69461 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.81139 / x: 389 / y: 208                                  │
# │ [pointed] LWrist (7) => prob: 0.74470 / x: 389 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.70724 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.74704 / x: 334 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.74482 / x: 334 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.61255 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.71725 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.42204 / x: 482 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.64894 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00604 / x: 538 / y: 333                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 114) <=> 1 (334, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 156) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (334, 208)                                                   │
# │ [linked] 3 (334, 208) <=> 4 (334, 240)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (389, 208)                                                   │
# │ [linked] 6 (389, 208) <=> 7 (389, 240)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 354)                                                   │
# │ [linked] 9 (334, 354) <=> 10 (334, 427)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (482, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9983469247817993 / x: 265 / y: 116 / width: 240 / height: 347         │
#   4%|▍         | 9/210 [00:10<04:00,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.86020 / x: 315 / y: 114                                    │
# │ [pointed] Neck (1) => prob: 0.84946 / x: 334 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.75144 / x: 315 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.34549 / x: 297 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.56571 / x: 278 / y: 187                                  │
# │ [pointed] LShoulder (5) => prob: 0.73503 / x: 371 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.67931 / x: 389 / y: 198                                  │
# │ [pointed] LWrist (7) => prob: 0.34644 / x: 371 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.62864 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.71581 / x: 334 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.66753 / x: 334 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.59021 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.62794 / x: 427 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.50601 / x: 482 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.70402 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00502 / x: 779 / y: 229                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 114) <=> 1 (334, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 2 (315, 177)                                                   │
# │ [linked] 1 (334, 156) <=> 5 (371, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (315, 177) <=> 3 (297, 219)                                                   │
# │ [linked] 3 (297, 219) <=> 4 (278, 187)                                                   │
# │ [linked] 5 (371, 156) <=> 6 (389, 198)                                                   │
# │ [linked] 6 (389, 198) <=> 7 (371, 240)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 354)                                                   │
# │ [linked] 9 (334, 354) <=> 10 (334, 427)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (427, 344)                                                 │
# │ [linked] 12 (427, 344) <=> 13 (482, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9954372644424438 / x: 270 / y: 113 / width: 235 / height: 351         │
#   5%|▍         | 10/210 [00:12<04:01,  1.21s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.77626 / x: 315 / y: 114                                    │
# │ [pointed] Neck (1) => prob: 0.71883 / x: 334 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.72077 / x: 334 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.69144 / x: 278 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.42570 / x: 278 / y: 198                                  │
# │ [pointed] LShoulder (5) => prob: 0.62780 / x: 371 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.51995 / x: 389 / y: 219                                  │
# │ [pointed] LWrist (7) => prob: 0.58357 / x: 352 / y: 260                                  │
# │ [pointed] RHip (8) => prob: 0.55258 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.68366 / x: 334 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.59135 / x: 315 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.61921 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.58850 / x: 445 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.47656 / x: 482 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.71912 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00535 / x: 259 / y: 271                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (315, 114) <=> 1 (334, 156)                                                   │
# │ [linked] 1 (334, 156) <=> 2 (334, 177)                                                   │
# │ [linked] 1 (334, 156) <=> 5 (371, 166)                                                   │
# │ [linked] 1 (334, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (334, 177) <=> 3 (278, 219)                                                   │
# │ [linked] 3 (278, 219) <=> 4 (278, 198)                                                   │
# │ [linked] 5 (371, 166) <=> 6 (389, 219)                                                   │
# │ [linked] 6 (389, 219) <=> 7 (352, 260)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 365)                                                   │
# │ [linked] 9 (334, 365) <=> 10 (315, 438)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (445, 354)                                                 │
# │ [linked] 12 (445, 354) <=> 13 (482, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.995328426361084 / x: 269 / y: 112 / width: 237 / height: 355          │
#   5%|▌         | 11/210 [00:13<04:00,  1.21s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.71456 / x: 334 / y: 114                                    │
# │ [pointed] Neck (1) => prob: 0.77066 / x: 352 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.78448 / x: 334 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.71293 / x: 315 / y: 208                                  │
# │ [pointed] RWrist (4) => prob: 0.48143 / x: 278 / y: 240                                  │
# │ [pointed] LShoulder (5) => prob: 0.65889 / x: 371 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.64870 / x: 389 / y: 229                                  │
# │ [pointed] LWrist (7) => prob: 0.68452 / x: 352 / y: 260                                  │
# │ [pointed] RHip (8) => prob: 0.54615 / x: 371 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.70706 / x: 334 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.67511 / x: 315 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.59648 / x: 408 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.51554 / x: 445 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.33758 / x: 464 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.74102 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00460 / x: 779 / y: 302                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (334, 114) <=> 1 (352, 156)                                                   │
# │ [linked] 1 (352, 156) <=> 2 (334, 177)                                                   │
# │ [linked] 1 (352, 156) <=> 5 (371, 166)                                                   │
# │ [linked] 1 (352, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (334, 177) <=> 3 (315, 208)                                                   │
# │ [linked] 3 (315, 208) <=> 4 (278, 240)                                                   │
# │ [linked] 5 (371, 166) <=> 6 (389, 229)                                                   │
# │ [linked] 6 (389, 229) <=> 7 (352, 260)                                                   │
# │ [linked] 8 (371, 281) <=> 9 (334, 365)                                                   │
# │ [linked] 9 (334, 365) <=> 10 (315, 438)                                                  │
# │ [linked] 11 (408, 281) <=> 12 (445, 354)                                                 │
# │ [linked] 12 (445, 354) <=> 13 (464, 417)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (371, 281)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (408, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9979782700538635 / x: 261 / y: 108 / width: 244 / height: 357         │
#   6%|▌         | 12/210 [00:14<03:57,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.82983 / x: 334 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.83938 / x: 352 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.80609 / x: 334 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.70245 / x: 315 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.52853 / x: 297 / y: 240                                  │
# │ [pointed] LShoulder (5) => prob: 0.63926 / x: 371 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.54062 / x: 389 / y: 219                                  │
# │ [pointed] LWrist (7) => prob: 0.47862 / x: 334 / y: 271                                  │
# │ [pointed] RHip (8) => prob: 0.56692 / x: 352 / y: 292                                    │
# │ [pointed] RKnee (9) => prob: 0.65069 / x: 334 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.66290 / x: 315 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.55362 / x: 389 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.57771 / x: 445 / y: 365                                  │
# │ [pointed] LAnkle (13) => prob: 0.53545 / x: 464 / y: 427                                 │
# │ [pointed] Chest (14) => prob: 0.62485 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00482 / x: 259 / y: 281                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (334, 104) <=> 1 (352, 156)                                                   │
# │ [linked] 1 (352, 156) <=> 2 (334, 177)                                                   │
# │ [linked] 1 (352, 156) <=> 5 (371, 166)                                                   │
# │ [linked] 1 (352, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (334, 177) <=> 3 (315, 219)                                                   │
# │ [linked] 3 (315, 219) <=> 4 (297, 240)                                                   │
# │ [linked] 5 (371, 166) <=> 6 (389, 219)                                                   │
# │ [linked] 6 (389, 219) <=> 7 (334, 271)                                                   │
# │ [linked] 8 (352, 292) <=> 9 (334, 365)                                                   │
# │ [linked] 9 (334, 365) <=> 10 (315, 438)                                                  │
# │ [linked] 11 (389, 281) <=> 12 (445, 365)                                                 │
# │ [linked] 12 (445, 365) <=> 13 (464, 427)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (352, 292)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (389, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9978001117706299 / x: 260 / y: 102 / width: 244 / height: 370         │
#   6%|▌         | 13/210 [00:15<03:56,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.71318 / x: 352 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.87776 / x: 352 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.79168 / x: 334 / y: 166                               │
# │ [pointed] RElbow (3) => prob: 0.66689 / x: 315 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.60755 / x: 297 / y: 260                                  │
# │ [pointed] LShoulder (5) => prob: 0.66739 / x: 389 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.49387 / x: 389 / y: 219                                  │
# │ [pointed] LWrist (7) => prob: 0.41824 / x: 334 / y: 271                                  │
# │ [pointed] RHip (8) => prob: 0.66052 / x: 352 / y: 292                                    │
# │ [pointed] RKnee (9) => prob: 0.60027 / x: 334 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.72108 / x: 315 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.60743 / x: 389 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.61415 / x: 445 / y: 365                                  │
# │ [pointed] LAnkle (13) => prob: 0.51998 / x: 464 / y: 438                                 │
# │ [pointed] Chest (14) => prob: 0.59722 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00467 / x: 259 / y: 313                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (352, 104) <=> 1 (352, 156)                                                   │
# │ [linked] 1 (352, 156) <=> 2 (334, 166)                                                   │
# │ [linked] 1 (352, 156) <=> 5 (389, 166)                                                   │
# │ [linked] 1 (352, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (334, 166) <=> 3 (315, 219)                                                   │
# │ [linked] 3 (315, 219) <=> 4 (297, 260)                                                   │
# │ [linked] 5 (389, 166) <=> 6 (389, 219)                                                   │
# │ [linked] 6 (389, 219) <=> 7 (334, 271)                                                   │
# │ [linked] 8 (352, 292) <=> 9 (334, 365)                                                   │
# │ [linked] 9 (334, 365) <=> 10 (315, 438)                                                  │
# │ [linked] 11 (389, 281) <=> 12 (445, 365)                                                 │
# │ [linked] 12 (445, 365) <=> 13 (464, 438)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (352, 292)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (389, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9981083273887634 / x: 283 / y: 102 / width: 212 / height: 372         │
#   7%|▋         | 14/210 [00:16<03:55,  1.20s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.70768 / x: 352 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.71368 / x: 352 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.80629 / x: 334 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.67477 / x: 315 / y: 229                                  │
# │ [pointed] RWrist (4) => prob: 0.61962 / x: 315 / y: 271                                  │
# │ [pointed] LShoulder (5) => prob: 0.72955 / x: 389 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.48457 / x: 389 / y: 219                                  │
# │ [pointed] LWrist (7) => prob: 0.18858 / x: 334 / y: 271                                  │
# │ [pointed] RHip (8) => prob: 0.61467 / x: 334 / y: 292                                    │
# │ [pointed] RKnee (9) => prob: 0.65675 / x: 315 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.64756 / x: 315 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.60999 / x: 389 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.56897 / x: 445 / y: 365                                  │
# │ [pointed] LAnkle (13) => prob: 0.56090 / x: 464 / y: 438                                 │
# │ [pointed] Chest (14) => prob: 0.68456 / x: 371 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00467 / x: 482 / y: 333                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (352, 104) <=> 1 (352, 156)                                                   │
# │ [linked] 1 (352, 156) <=> 2 (334, 177)                                                   │
# │ [linked] 1 (352, 156) <=> 5 (389, 166)                                                   │
# │ [linked] 1 (352, 156) <=> 14 (371, 229)                                                  │
# │ [linked] 2 (334, 177) <=> 3 (315, 229)                                                   │
# │ [linked] 3 (315, 229) <=> 4 (315, 271)                                                   │
# │ [linked] 5 (389, 166) <=> 6 (389, 219)                                                   │
# │ [linked] 6 (389, 219) <=> 7 (334, 271)                                                   │
# │ [linked] 8 (334, 292) <=> 9 (315, 365)                                                   │
# │ [linked] 9 (315, 365) <=> 10 (315, 438)                                                  │
# │ [linked] 11 (389, 281) <=> 12 (445, 365)                                                 │
# │ [linked] 12 (445, 365) <=> 13 (464, 438)                                                 │
# │ [linked] 14 (371, 229) <=> 8 (334, 292)                                                  │
# │ [linked] 14 (371, 229) <=> 11 (389, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9989935159683228 / x: 282 / y: 101 / width: 208 / height: 376         │
#   7%|▋         | 15/210 [00:18<03:56,  1.21s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.74292 / x: 389 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.82169 / x: 371 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.81018 / x: 334 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.58877 / x: 315 / y: 229                                  │
# │ [pointed] RWrist (4) => prob: 0.58999 / x: 315 / y: 271                                  │
# │ [pointed] LShoulder (5) => prob: 0.70061 / x: 389 / y: 177                               │
# │ [pointed] LElbow (6) => prob: 0.42029 / x: 389 / y: 229                                  │
# │ [pointed] LWrist (7) => prob: 0.41803 / x: 334 / y: 271                                  │
# │ [pointed] RHip (8) => prob: 0.59215 / x: 334 / y: 302                                    │
# │ [pointed] RKnee (9) => prob: 0.65760 / x: 315 / y: 375                                   │
# │ [pointed] RAnkle (10) => prob: 0.64610 / x: 297 / y: 448                                 │
# │ [pointed] LHip (11) => prob: 0.59078 / x: 389 / y: 292                                   │
# │ [pointed] LKnee (12) => prob: 0.64550 / x: 427 / y: 365                                  │
# │ [pointed] LAnkle (13) => prob: 0.48145 / x: 464 / y: 448                                 │
# ...
# │ [pointed] RElbow (3) => prob: 0.76927 / x: 222 / y: 219                                  │
# │ [pointed] RWrist (4) => prob: 0.61341 / x: 241 / y: 281                                  │
# │ [pointed] LShoulder (5) => prob: 0.75958 / x: 297 / y: 156                               │
# │ [pointed] LElbow (6) => prob: 0.55685 / x: 297 / y: 208                                  │
# │ [pointed] LWrist (7) => prob: 0.28849 / x: 297 / y: 240                                  │
# │ [pointed] RHip (8) => prob: 0.60733 / x: 259 / y: 271                                    │
# │ [pointed] RKnee (9) => prob: 0.72465 / x: 259 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.65422 / x: 259 / y: 417                                 │
# │ [pointed] LHip (11) => prob: 0.64670 / x: 315 / y: 271                                   │
# │ [pointed] LKnee (12) => prob: 0.75972 / x: 334 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.80392 / x: 297 / y: 406                                 │
# │ [pointed] Chest (14) => prob: 0.69669 / x: 278 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00677 / x: 445 / y: 323                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (297, 83) <=> 1 (278, 135)                                                    │
# │ [linked] 1 (278, 135) <=> 2 (241, 156)                                                   │
# │ [linked] 1 (278, 135) <=> 5 (297, 156)                                                   │
# │ [linked] 1 (278, 135) <=> 14 (278, 219)                                                  │
# │ [linked] 2 (241, 156) <=> 3 (222, 219)                                                   │
# │ [linked] 3 (222, 219) <=> 4 (241, 281)                                                   │
# │ [linked] 5 (297, 156) <=> 6 (297, 208)                                                   │
# │ [linked] 6 (297, 208) <=> 7 (297, 240)                                                   │
# │ [linked] 8 (259, 271) <=> 9 (259, 354)                                                   │
# │ [linked] 9 (259, 354) <=> 10 (259, 417)                                                  │
# │ [linked] 11 (315, 271) <=> 12 (334, 344)                                                 │
# │ [linked] 12 (334, 344) <=> 13 (297, 406)                                                 │
# │ [linked] 14 (278, 219) <=> 8 (259, 271)                                                  │
# │ [linked] 14 (278, 219) <=> 11 (315, 271)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9969184994697571 / x: 222 / y: 85 / width: 123 / height: 380          │
#  99%|█████████▊| 207/210 [04:12<00:03,  1.22s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.78710 / x: 297 / y: 83                                     │
# │ [pointed] Neck (1) => prob: 0.75304 / x: 278 / y: 135                                    │
# │ [pointed] RShoulder (2) => prob: 0.76754 / x: 241 / y: 166                               │
# │ [pointed] RElbow (3) => prob: 0.75138 / x: 222 / y: 229                                  │
# │ [pointed] RWrist (4) => prob: 0.67197 / x: 222 / y: 292                                  │
# │ [pointed] LShoulder (5) => prob: 0.74533 / x: 297 / y: 166                               │
# │ [pointed] LElbow (6) => prob: 0.58236 / x: 297 / y: 208                                  │
# │ [pointed] LWrist (7) => prob: 0.30000 / x: 297 / y: 250                                  │
# │ [pointed] RHip (8) => prob: 0.56500 / x: 259 / y: 271                                    │
# │ [pointed] RKnee (9) => prob: 0.69803 / x: 259 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.70677 / x: 259 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.71202 / x: 297 / y: 271                                   │
# │ [pointed] LKnee (12) => prob: 0.83537 / x: 315 / y: 344                                  │
# │ [pointed] LAnkle (13) => prob: 0.78573 / x: 297 / y: 406                                 │
# │ [pointed] Chest (14) => prob: 0.69666 / x: 278 / y: 219                                  │
# │ [pointed] Background (15) => prob: 1.00734 / x: 445 / y: 313                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (297, 83) <=> 1 (278, 135)                                                    │
# │ [linked] 1 (278, 135) <=> 2 (241, 166)                                                   │
# │ [linked] 1 (278, 135) <=> 5 (297, 166)                                                   │
# │ [linked] 1 (278, 135) <=> 14 (278, 219)                                                  │
# │ [linked] 2 (241, 166) <=> 3 (222, 229)                                                   │
# │ [linked] 3 (222, 229) <=> 4 (222, 292)                                                   │
# │ [linked] 5 (297, 166) <=> 6 (297, 208)                                                   │
# │ [linked] 6 (297, 208) <=> 7 (297, 250)                                                   │
# │ [linked] 8 (259, 271) <=> 9 (259, 354)                                                   │
# │ [linked] 9 (259, 354) <=> 10 (259, 427)                                                  │
# │ [linked] 11 (297, 271) <=> 12 (315, 344)                                                 │
# │ [linked] 12 (315, 344) <=> 13 (297, 406)                                                 │
# │ [linked] 14 (278, 219) <=> 8 (259, 271)                                                  │
# │ [linked] 14 (278, 219) <=> 11 (297, 271)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9969133734703064 / x: 204 / y: 99 / width: 134 / height: 368          │
#  99%|█████████▉| 208/210 [04:14<00:02,  1.22s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.81412 / x: 278 / y: 93                                     │
# │ [pointed] Neck (1) => prob: 0.72695 / x: 259 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.80973 / x: 222 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.84648 / x: 204 / y: 240                                  │
# │ [pointed] RWrist (4) => prob: 0.73590 / x: 222 / y: 302                                  │
# │ [pointed] LShoulder (5) => prob: 0.78136 / x: 278 / y: 177                               │
# │ [pointed] LElbow (6) => prob: 0.61745 / x: 278 / y: 229                                  │
# │ [pointed] LWrist (7) => prob: 0.44868 / x: 278 / y: 260                                  │
# │ [pointed] RHip (8) => prob: 0.61902 / x: 241 / y: 281                                    │
# │ [pointed] RKnee (9) => prob: 0.68162 / x: 241 / y: 354                                   │
# │ [pointed] RAnkle (10) => prob: 0.76979 / x: 241 / y: 438                                 │
# │ [pointed] LHip (11) => prob: 0.74174 / x: 278 / y: 281                                   │
# │ [pointed] LKnee (12) => prob: 0.74812 / x: 297 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.89094 / x: 278 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.75448 / x: 259 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00461 / x: 427 / y: 323                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (278, 93) <=> 1 (259, 156)                                                    │
# │ [linked] 1 (259, 156) <=> 2 (222, 177)                                                   │
# │ [linked] 1 (259, 156) <=> 5 (278, 177)                                                   │
# │ [linked] 1 (259, 156) <=> 14 (259, 229)                                                  │
# │ [linked] 2 (222, 177) <=> 3 (204, 240)                                                   │
# │ [linked] 3 (204, 240) <=> 4 (222, 302)                                                   │
# │ [linked] 5 (278, 177) <=> 6 (278, 229)                                                   │
# │ [linked] 6 (278, 229) <=> 7 (278, 260)                                                   │
# │ [linked] 8 (241, 281) <=> 9 (241, 354)                                                   │
# │ [linked] 9 (241, 354) <=> 10 (241, 438)                                                  │
# │ [linked] 11 (278, 281) <=> 12 (297, 354)                                                 │
# │ [linked] 12 (297, 354) <=> 13 (278, 417)                                                 │
# │ [linked] 14 (259, 229) <=> 8 (241, 281)                                                  │
# │ [linked] 14 (259, 229) <=> 11 (278, 281)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9948840141296387 / x: 196 / y: 104 / width: 139 / height: 363         │
# 100%|█████████▉| 209/210 [04:15<00:01,  1.23s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.79302 / x: 278 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.78880 / x: 259 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.76030 / x: 222 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.77002 / x: 204 / y: 240                                  │
# │ [pointed] RWrist (4) => prob: 0.78976 / x: 204 / y: 302                                  │
# │ [pointed] LShoulder (5) => prob: 0.76364 / x: 278 / y: 177                               │
# │ [pointed] LElbow (6) => prob: 0.48756 / x: 259 / y: 229                                  │
# │ [pointed] LWrist (7) => prob: 0.24287 / x: 278 / y: 271                                  │
# │ [pointed] RHip (8) => prob: 0.65658 / x: 222 / y: 292                                    │
# │ [pointed] RKnee (9) => prob: 0.71442 / x: 241 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.65753 / x: 241 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.68716 / x: 278 / y: 292                                   │
# │ [pointed] LKnee (12) => prob: 0.86225 / x: 297 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.74264 / x: 259 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.62286 / x: 241 / y: 229                                  │
# │ [pointed] Background (15) => prob: 1.00696 / x: 408 / y: 323                             │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (278, 104) <=> 1 (259, 156)                                                   │
# │ [linked] 1 (259, 156) <=> 2 (222, 177)                                                   │
# │ [linked] 1 (259, 156) <=> 5 (278, 177)                                                   │
# │ [linked] 1 (259, 156) <=> 14 (241, 229)                                                  │
# │ [linked] 2 (222, 177) <=> 3 (204, 240)                                                   │
# │ [linked] 3 (204, 240) <=> 4 (204, 302)                                                   │
# │ [linked] 5 (278, 177) <=> 6 (259, 229)                                                   │
# │ [linked] 6 (259, 229) <=> 7 (278, 271)                                                   │
# │ [linked] 8 (222, 292) <=> 9 (241, 365)                                                   │
# │ [linked] 9 (241, 365) <=> 10 (241, 427)                                                  │
# │ [linked] 11 (278, 292) <=> 12 (297, 354)                                                 │
# │ [linked] 12 (297, 354) <=> 13 (259, 417)                                                 │
# │ [linked] 14 (241, 229) <=> 8 (222, 292)                                                  │
# │ [linked] 14 (241, 229) <=> 11 (278, 292)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│
# │────────────────────────────────────────── YOLO ──────────────────────────────────────────│
# │ [person_1] conf: 0.9922239780426025 / x: 187 / y: 107 / width: 137 / height: 361         │
# 100%|██████████| 210/210 [04:16<00:00,  1.22s/it]
# │───────────────────────────────────────── POINT ──────────────────────────────────────────│
# │ [pointed] Head (0) => prob: 0.75632 / x: 278 / y: 104                                    │
# │ [pointed] Neck (1) => prob: 0.68049 / x: 241 / y: 156                                    │
# │ [pointed] RShoulder (2) => prob: 0.71600 / x: 222 / y: 177                               │
# │ [pointed] RElbow (3) => prob: 0.71681 / x: 185 / y: 250                                  │
# │ [pointed] RWrist (4) => prob: 0.81035 / x: 204 / y: 302                                  │
# │ [pointed] LShoulder (5) => prob: 0.74371 / x: 259 / y: 177                               │
# │ [pointed] LElbow (6) => prob: 0.59493 / x: 259 / y: 229                                  │
# │ [pointed] LWrist (7) => prob: 0.36363 / x: 278 / y: 281                                  │
# │ [pointed] RHip (8) => prob: 0.74221 / x: 222 / y: 292                                    │
# │ [pointed] RKnee (9) => prob: 0.71833 / x: 241 / y: 365                                   │
# │ [pointed] RAnkle (10) => prob: 0.73811 / x: 222 / y: 427                                 │
# │ [pointed] LHip (11) => prob: 0.68536 / x: 278 / y: 292                                   │
# │ [pointed] LKnee (12) => prob: 0.70956 / x: 297 / y: 354                                  │
# │ [pointed] LAnkle (13) => prob: 0.79869 / x: 259 / y: 417                                 │
# │ [pointed] Chest (14) => prob: 0.69423 / x: 241 / y: 240                                  │
# │ [pointed] Background (15) => prob: 1.00384 / x: 55 / y: 146                              │
# │────────────────────────────────────────── LINK ──────────────────────────────────────────│
# │ [linked] 0 (278, 104) <=> 1 (241, 156)                                                   │
# │ [linked] 1 (241, 156) <=> 2 (222, 177)                                                   │
# │ [linked] 1 (241, 156) <=> 5 (259, 177)                                                   │
# │ [linked] 1 (241, 156) <=> 14 (241, 240)                                                  │
# │ [linked] 2 (222, 177) <=> 3 (185, 250)                                                   │
# │ [linked] 3 (185, 250) <=> 4 (204, 302)                                                   │
# │ [linked] 5 (259, 177) <=> 6 (259, 229)                                                   │
# │ [linked] 6 (259, 229) <=> 7 (278, 281)                                                   │
# │ [linked] 8 (222, 292) <=> 9 (241, 365)                                                   │
# │ [linked] 9 (241, 365) <=> 10 (222, 427)                                                  │
# │ [linked] 11 (278, 292) <=> 12 (297, 354)                                                 │
# │ [linked] 12 (297, 354) <=> 13 (259, 417)                                                 │
# │ [linked] 14 (241, 240) <=> 8 (222, 292)                                                  │
# │ [linked] 14 (241, 240) <=> 11 (278, 292)                                                 │
# │───────────────────────────────────────── IN BOX ─────────────────────────────────────────│

# %%
import glob

img_array = []

for file in tqdm(glob.glob('/content/drive/MyDrive/test/*.jpg')):
    img = cv2.imread(file)
    img_array.append(img)

height, width = img.shape[:2]
size = (width, height)
video = cv2.VideoWriter('/content/drive/MyDrive/test/result.avi',cv2.VideoWriter_fourcc(*'DIVX'), 20, size)

for img in img_array:
    video.write(img)

video.release()
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]
#  10%|█         | 21/210 [00:00<00:00, 200.74it/s]
#  20%|█▉        | 41/210 [00:00<00:00, 197.81it/s]
#  28%|██▊       | 59/210 [00:00<00:00, 191.39it/s]
#  37%|███▋      | 78/210 [00:00<00:00, 188.31it/s]
#  46%|████▌     | 96/210 [00:00<00:00, 185.22it/s]
#  55%|█████▍    | 115/210 [00:00<00:00, 186.59it/s]
#  64%|██████▍   | 135/210 [00:00<00:00, 188.08it/s]
#  73%|███████▎  | 154/210 [00:00<00:00, 186.30it/s]
#  82%|████████▏ | 173/210 [00:00<00:00, 185.81it/s]
#  91%|█████████ | 191/210 [00:01<00:00, 177.29it/s]
# 100%|██████████| 210/210 [00:01<00:00, 182.94it/s]
